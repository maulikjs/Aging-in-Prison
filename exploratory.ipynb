# %%
#libraries
import pandas as pd

#read data

term_records = pd.DataFrame.from_csv('data/DS0001/36404-0001-Data.tsv', sep='\t', header=0)
prison_admissions = pd.DataFrame.from_csv('data/DS0002/36404-0002-Data.tsv', sep='\t', header=0)
prison_releases = pd.DataFrame.from_csv('data/DS0003/36404-0003-Data.tsv', sep='\t', header=0)
year_end_population = pd.DataFrame.from_csv('data/DS0004/36404-0004-Data.tsv', sep='\t', header=0)
# Out:
# /Users/lubovmckone/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# /Users/lubovmckone/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
term_records.head(20)
# Out:
#                      SEX  ADMTYPE  OFFGENERAL  EDUCATION  ADMITYR  RELEASEYR  \
# ABT_INMATE_ID
# A012015000000091071    1        1           2          9     2006       2010
# A022015000000096906    1        3           3          9     2008       2008
# A042015000000118649    1        1           1          9     2013       2014
# A062015000000167469    1        2           2          9     1996       1996
# A132015000000550479    1        1           1          9     1968       1972
# A172015000000995085    1        1           1          9     2006       2009
# A182015000000019353    2        3           3          9     2008       2009
# A202015000000031529    1        1           3          9     2013       2014
# A212015000000115891    1        2           4          9     2014       2014
# A232015000000003075    1        1           1          9     2012       2014
# A242015000000177833    1        1           1          9     1999       9999
# ...

# %%
prison_admissions.groupby(['OFFDETAIL', 'RACE', 'AGEADMIT'])['AGEADMIT'].count()
# Out:
# OFFDETAIL  RACE  AGEADMIT
# 1          1     1           12377
#                  2           15771
#                  3           13519
#                  4            9002
#                  5            4704
#            2     1           34930
#                  2           30095
#                  3           16542
#                  4            8225
#                  5            3134
#            3     1           19253
#                  2           14788
#                  3            6588
#                  4            2791
#                  5            1183
#            4     1            2223
#                  2            1949
#                  3            1148
#                  4             664
#                  5             306
#            9     1           22844
#                  2           14342
#                  3            9094
#                  4            4740
#                  5            2048
# 2          1     1            7503
# ...
